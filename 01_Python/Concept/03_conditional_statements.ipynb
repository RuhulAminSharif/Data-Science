# %% [markdown]
# ## **If-else in Python**

# %%
# login program and indentation
# email -> name.company@gmail.com
# password -> 1234

email = input('enter email: ')
password = input('enter password: ')

if email == "name.company@gmail.com" and password == "1234":
    print("Welcome")
elif email == "name.company@gmail.com" and password != "1234":
    print("Incorrect Password")
    password = input('enter password again: ')
    if password == "1234":
        print("Welcome, finally!")
    else:
        print("You can't do it")
else:
    print("Not Correct")
# Out:
# enter email: name.company@gmail.com
# enter password: 4578
# Incorrect Password
# enter password again: 1234
# Welcome, finally!

# %%
# if-else examples
# 1. Find the min of 3 given numbers
# 2. Menu Driven Program

# %%
# min of 3 number

a = int(input('first num: '))
b = int(input('second num: '))
c = int(input('third num: '))

if a < b and a < c:
    print("Smallest Number: ", a )
elif b < c:
    print("Smallest Number: ", b )
else:
    print("Smallest Number: ", c )
# Out:
# first num: 4
# second num: 8
# third num: 2
# Smallest Number:  2

# %%
# menu driven calculator
fnum = int(input("Enter the 1st Number: "))
snum = int(input("Enter the 2nd Number: "))

op = input("""
Enter the Operation
1. For Addition: '+'
2. For Subtraction: '-'
3. For Multiplication: '*'
4. For Division: '/'
""")

if op == '+':
    print(fnum + snum)
elif op == '-':
    print(fnum - snum)
elif op == '*':
    print(fnum * snum)
elif op == '/':
    print(fnum / snum)
else:
    print("Not valid operator")
# Out:
# Enter the 1st Number: 4
# Enter the 2nd Number: 8
#
# Enter the Operation
# 1. For Addition: '+'
# 2. For Subtraction: '-'
# 3. For Multiplication: '*'
# 4. For Division: '/'
# +
# 12

# %%
menu = input("""
Hi! how can I help you.
1. Enter 1 for pin change
2. Enter 2 for balance check
3. Enter 3 for withdrawl
4. Enter 4 for exit
""")

if menu == '1':
    print("pin change")
elif menu == '2':
    print("balance check")
elif menu == '3':
    print("withdrawl")
else:
    print("exit")
# Out:
# Hi! how can I help you.
# 1. Enter 1 for pin change
# 2. Enter 2 for balance check
# 3. Enter 3 for withdrawl
# 4. Enter 4 for exit
# 3
# withdrawl
