# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### `Q-1:` Write a program to create an empty series.

# %%
# code here
series = pd.Series()
print(series)
# Out:
# Series([], dtype: object)

# %% [markdown]
# ### `Q-2:` Write a Pandas program to add, subtract, multiply and divide two Pandas Series.

# %%
# code here
a = pd.Series([2, 4, 6, 8, 10])
b = pd.Series([1, 3, 5, 7, 10])
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 0     3
# 1     7
# 2    11
# 3    15
# 4    20
# dtype: int64
# 0    1
# 1    1
# 2    1
# 3    1
# 4    0
# dtype: int64
# 0      2
# 1     12
# 2     30
# 3     56
# 4    100
# dtype: int64
# 0    2.000000
# 1    1.333333
# 2    1.200000
# 3    1.142857
# 4    1.000000
# dtype: float64

# %% [markdown]
# ### `Q-3` Write a Pandas program to compare the elements of the two Pandas Series.
# Sample Series: [2, 4, 6, 8, 10], [1, 3, 5, 7, 10]

# %%
# code here
a = pd.Series([2, 4, 6, 8, 10])
b = pd.Series([1, 3, 5, 7, 10])
print(a == b)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %% [markdown]
# ### `Q-5.`Write a function to change the data type of given a column or a Series. Function takes series and data type as input, returns the converted series.
# ```
# series = pd.Series([1,2,'Python', 2.0, True, 100])
# change to float type data
# ```

# %%
# code here
series = pd.Series([1,2,'Python', 2.0, True, 100])
pd.to_numeric(series, errors='coerce')
# Out:
# 0      1.0
# 1      2.0
# 2      NaN
# 3      2.0
# 4      1.0
# 5    100.0
# dtype: float64

# %% [markdown]
# Download data - https://drive.google.com/file/d/1LRhXwbEodeWXtzPhJCX0X9Lf_BECzvqb/view?usp=share_link
# All Batsman runs series in IPL 2008 to 2022.
#
# Below questions are based on this data.

# %%
runs = pd.read_csv('/content/batsman_runs_series.csv')
print(type(runs))
print(runs)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#              batter  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 2        A Chandila            4
# 3          A Chopra           53
# 4       A Choudhary           25
# ..              ...          ...
# 600      Yash Dayal            0
# 601   Yashpal Singh           47
# 602     Younis Khan            3
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [605 rows x 2 columns]

# %% [markdown]
# ###`Q-6` Find top 10 most run getter from the series.

# %%
# code here
runs.sort_values("batsman_run", ascending=False).head(10)
# Out:
#              batter  batsman_run
# 569         V Kohli         6634
# 462        S Dhawan         6244
# 130       DA Warner         5883
# 430       RG Sharma         5881
# 493        SK Raina         5536
# 27   AB de Villiers         5181
# 108        CH Gayle         4997
# 339        MS Dhoni         4978
# 452      RV Uthappa         4954
# 256      KD Karthik         4377

# %% [markdown]
# ###`Q-7` No of players having runs above 3000

# %%
# code here
runs[ runs['batsman_run'] > 3000 ].shape[0]
# Out:
# 20

# %% [markdown]
# ###`Q-8` No of players having runs above mean value?

# %%
# code here
runs[ runs['batsman_run'] > runs['batsman_run'].mean() ].shape[0]
# Out:
# 128

# %% [markdown]
# Download data - https://drive.google.com/file/d/1QZuZ5bypUInfVvarHACLAi8tXXHvb8xd/view?usp=share_link
#
# file name - items.csv

# %% [markdown]
# ###`Q-9`
#     i. Read `items.csv` making `item_name` as index.
#     ii. Show no of nan values
#     iii. Item price is given in $, so convert it to taka without currency symbol.
#     iv. Make data type of newly made series as float.
#     v. Fill nan with mean of the series
#
#
# How csv file looks
#
# ```
# item_name	item_price
# Chips and Fresh Tomato Salsa	$2.39
# Izze	$3.39
# Nantucket Nectar	$3.39
# Chips and Tomatillo-Green Chili Salsa	$2.39
# Chicken Bowl	$16.98
#
# ```

# %%
# code here
# i
items = pd.read_csv('/content/items.csv', index_col='item_name')
# ii
print(items.isna().sum())

## iii.
def to_taka(dollar):
    try:
        y = dollar[1:]
    except:
        y = dollar

    return float(y) * 120

items['item_price'] = items['item_price'].apply(to_taka)

## iv.
items['item_price'] = items['item_price'].astype(float)

## v.
mean_taka = items['item_price'].mean()
items['item_price'] = items['item_price'].fillna(mean_taka)

items
# Out:
# item_price    50
# dtype: int64
#                                        item_price
# item_name
# Chips and Fresh Tomato Salsa                286.8
# Izze                                        406.8
# Nantucket Nectar                            406.8
# Chips and Tomatillo-Green Chili Salsa       286.8
# Chicken Bowl                               2037.6
# ...                                           ...
# Steak Burrito                              1410.0
# Steak Burrito                              1410.0
# Chicken Salad Bowl                         1350.0
# Chicken Salad Bowl                         1050.0
# Chicken Salad Bowl                         1050.0
#
# [4622 rows x 1 columns]

# %% [markdown]
# ###`Q-10`:
#     i. Find mean price
#     ii. Find 30th and 6th percentile value
#     iii. Plot Histogram on price with bin size 50
#     iv. No of items price lies between [1000 to 2000]

# %%
# code here

# i
print(items.mean())

# ii
print(items.quantile(0.3))
print(items.quantile(0.06))

# iii
items.plot.hist(bins=50)

# iv
print(items[(items['item_price'] >= 1000) & (items['item_price'] <= 2000)].shape[0])
# Out:
# item_price    895.56378
# dtype: float64
# item_price    534.0
# Name: 0.3, dtype: float64
# item_price    150.0
# Name: 0.06, dtype: float64
# 2721
