# %% [markdown]
# ### Q1 :- Print the given strings as per stated format.
#
# **Given strings**:
# ```
# "Data" "Science" "Mentorship" "Program"
# "By" "CampusX"
# ```
# **Output**:
# ```
# Data-Science-Mentorship-Program-started-By-CampusX
# ```
#
# Concept- [Seperator and End]

# %%
# Write your code here

print("Data", "Science", "Mentorship", "Program", sep="-", end="-started-")
print("By", "CampusX", sep='-')
# Out:
# Data-Science-Mentorship-Program-started-By-CampusX

# %% [markdown]
# ### Q2:- Write a program that will convert celsius value to fahrenheit.

# %%
# Write your code here
celsius = float(input("Enter Temparature in Celsius: "))
fahrenheit = (celsius * 9/5) + 32
print(fahrenheit)
# Out:
# Enter Temparature in Celsius: 37
# 98.6

# %% [markdown]
# ### Q3:- Take 2 numbers as input from the user. Write a program to swap the numbers without using any special python syntax.

# %%
# Write your code here
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
print("---before swap---")
print("a: ", a)
print("b: ", b)
temp = a
a = b
b = temp
print("---after swap---")
print("a: ", a)
print("b: ", b)
# Out:
# Enter first number: 5
# Enter second number: 7
# ---before swap---
# a:  5
# b:  7
# ---after swap---
# a:  7
# b:  5

# %% [markdown]
# ### Q4:- Write a program to find the euclidean distance between two coordinates.Take both the coordinates from the user as input.

# %%
# Write your code here
x1 = float(input("Enter x-coordinate of point 1: "))
y1 = float(input("Enter y-coordinate of point 1: "))
x2 = float(input("Enter x-coordinate of point 2: "))
y2 = float(input("Enter y-coordinate of point 2: "))
distance = ( ( x1 - x2 ) ** 2 + ( y1 - y2 ) ** 2 ) ** 0.5
print(distance)
# Out:
# Enter x-coordinate of point 1: 0
# Enter y-coordinate of point 1: 0
# Enter x-coordinate of point 2: 2
# Enter y-coordinate of point 2: 0
# 2.0

# %% [markdown]
# ### Q5:- Write a program to find the simple interest when the value of principle, rate of interest and time period is provided by the user.

# %%
# Write your code here
principle = float(input("Enter principle amount: "))
rate_of_interest = float(input("Enter rate of interest: "))
time_period = float(input("Enter time period in years: "))
simple_interest = (principle * rate_of_interest * time_period) / 100
print(f"Simple Interest: {simple_interest}")
# Out:
# Enter principle amount: 100
# Enter rate of interest: 5
# Enter time period in years: 2
# Simple Interest: 10.0

# %% [markdown]
# ### Q6:- Write a program that will tell the number of dogs and chicken are there when the user will provide the value of total heads and legs.
#
# For example:
# Input:
# heads -> 4
# legs -> 12
# <br>
# Output:
# dogs -> 2
# chicken -> 2

# %%
# Write your code here
# C + D = H => D = H - C

# 2C + 4D = L
# 2( C + 2D ) = L
# 2( C + D + D ) = L
# 2( H + D ) = L
# 2( H + H - C ) = L
# 2( 2H - C ) = L
# 4H - 2C = L
# 2C = 4H - L
# C = (4H - L) / 2

heads = int(input("Enter total number of heads: "))
legs = int(input("Enter total number of legs: "))
chickens = (4 * heads - legs) / 2
dogs = heads - chickens
print(f"Chickens: {int(chickens)}")
print(f"Dogs: {int(dogs)}")
# Out:
# Enter total number of heads: 2
# Enter total number of legs: 6
# Chickens: 1
# Dogs: 1

# %% [markdown]
# ### Q7:- Write a program to find the sum of squares of first n natural numbers where n will be provided by the user.

# %%
# Write your code here
n = int(input("Enter the number: "))
sum = n * (n + 1) * (2 * n + 1) / 6
print(f"Sum of squares: {sum}")
# Out:
# Enter the number: 5
# Sum of squares: 55.0

# %% [markdown]
# ### Q8:- Given the first 2 terms of an Arithmetic Series. Find the Nth term of the series. Assume all inputs are provided by the user.

# %%
# Write your code here
first_term = int(input("Enter the first term: "))
second_term = int(input("Enter the second term: "))
n = int(input("Enter the value of n: "))
difference = second_term - first_term
n_term = first_term + (n - 1) * difference
print(f"Nth term: {n_term}")
# Out:
# Enter the first term: 1
# Enter the second term: 2
# Enter the value of n: 10
# Nth term: 10

# %% [markdown]
# ### Q9:- Given 2 fractions, find the sum of those 2 fractions. Take the numerator and denominator values of the fractions from the user.

# %%
# Write your code here
num1 = int(input("Enter numerator of the first fraction: "))
den1 = int(input("Enter denominator of the first fraction: "))
num2 = int(input("Enter numerator of the second fraction: "))
den2 = int(input("Enter denominator of the second fraction: "))
fraction_num = (num1 * den2) + (num2 * den1)
fraction_den = den1 * den2
print('{}/{}'.format(fraction_num, fraction_den))
# Out:
# Enter numerator of the first fraction: 1
# Enter denominator of the first fraction: 4
# Enter numerator of the second fraction: 3
# Enter denominator of the second fraction: 4
# 16/16

# %% [markdown]
# ### Q10:- Given the height, width and breadth of a milk tank, you have to find out how many glasses of milk can be obtained? Assume all the inputs are provided by the user.
#
#
#
# Input:<br>
# Dimensions of the milk tank<br>
# H = 20cm, L = 20cm, B = 20cm
# <br><br>
# Dimensions of the glass<br>
# h = 3cm, r = 1cm

# %%
# Write your code here
import math
length = float(input("Enter the length of the milk tank: "))
breadth = float(input("Enter the breadth of the milk tank: "))
height = float(input("Enter the height of the milk tank: "))

glass_height = float(input("Enter the height of the glass: "))
glass_radius = float(input("Enter the radius of the glass: "))

tank_volume = length * breadth * height
glass_volume = 3.14 * glass_radius**2 * glass_height

number_of_glasses = math.floor(tank_volume / glass_volume)

print(f"Number of glasses: {number_of_glasses}")
# Out:
# Enter the length of the milk tank: 10
# Enter the breadth of the milk tank: 19
# Enter the height of the milk tank: 10
# Enter the height of the glass: 5
# Enter the radius of the glass: 2
# Number of glasses: 30
